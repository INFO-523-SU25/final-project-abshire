# %%
## https://github.com/stephen1694/pybaseball/blob/main/download_2015_2024.py

## step 1: download pitch level data for each year

# import modules
from pybaseball import statcast
import pandas as pd
from calendar import monthrange

def download_statcast_data(year, start_day, end_day):
    """
    Download Statcast data for a given year, starting and ending at specific dates.

    Parameters:
    - year: String, last two digits of the year (e.g., '15' for 2015)
    - start_day: String, the starting day in 'MM-DD' format (e.g., '03-15' for March 15)
    - end_day: String, the ending day in 'MM-DD' format (e.g., '10-05' for October 5)

    Returns finalDf: DataFrame with Statcast data for the specified range of the season
    """
    # Convert start and end days to full dates
    start_date = f"20{year}-{start_day}"
    end_date = f"20{year}-{end_day}"

    # Extract start and end months
    start_month = int(start_day.split('-')[0])
    end_month = int(end_day.split('-')[0])

    # Generate the list of months between the start and end
    list_months = [f"{month:02d}" for month in range(start_month, end_month + 1)]

    # Make an empty list for dataframes
    list_dfs = []

    # Download Statcast data month by month
    for i, month in enumerate(list_months):
        # Define start and end dates for the month
        if i == 0:  # First month
            start = start_date
            _, last_day = monthrange(int(f"20{year}"), int(month))
            end = f"20{year}-{month}-{last_day:02d}" if len(list_months) > 1 else end_date
        elif i == len(list_months) - 1:  # Last month
            start = f"20{year}-{month}-01"
            end = end_date
        else:  # Middle months
            start = f"20{year}-{month}-01"
            _, last_day = monthrange(int(f"20{year}"), int(month))
            end = f"20{year}-{month}-{last_day:02d}"

        print(f"Downloading data from {start} to {end}")
        data = statcast(start_dt=start, end_dt=end)
        list_dfs.append(data)

    # Concatenate dataframes in list_dfs to one dataframe called finalDf
    finalDf = pd.concat(list_dfs)

    # Drop duplicates from finalDf
    finalDf = finalDf.drop_duplicates()

    return finalDf

#pitch_2015_df = download_statcast_data('25', '04-10', '04-15')
#pitch_2015_df.to_csv('pitch_2015.csv')

#pitch_2016_df = download_statcast_data('16', '04-03', '10-02')
#pitch_2016_df = pitch_2016_df[~((pitch_2016_df['game_date'] == '2016-04-03') & (~pitch_2016_df['home_team'].isin(['PIT', 'KC', 'TB'])))] # drop spring games ((all except PIT, KC, TB home games)
#pitch_2016_df.to_csv('pitch_2016.csv')

#pitch_2017_df = download_statcast_data('17', '04-02', '10-01')
#pitch_2017_df.to_csv('pitch_2017.csv')

#pitch_2018_df = download_statcast_data('18', '03-29', '10-01')
#pitch_2018_df.to_csv('pitch_2018.csv')

#pitch_2019_df = download_statcast_data('19', '03-20', '09-30')
#pitch_2019_df = pitch_2019_df[~((pitch_2019_df['game_date'] == '2019-03-20') & (~pitch_2019_df['home_team'].isin(['SEA', 'OAK'])))] # drop non Japan series games 3/20
#pitch_2019_df = pitch_2019_df[~((pitch_2019_df['game_date'] == '2019-03-21') & (~pitch_2019_df['home_team'].isin(['SEA', 'OAK'])))] # drop non Japan series games 3/21
#dates_to_drop_19 = ['2019-03-22','2019-03-23','2019-03-24','2019-03-25','2019-03-26','2019-03-27'] # drop all games 3/22-3/27
#pitch_2019_df = pitch_2019_df[~pitch_2019_df['game_date'].isin(dates_to_drop_19)]
#pitch_2019_df.to_csv('pitch_2019.csv')

#pitch_2020_df = download_statcast_data('20', '07-23', '09-27')
#pitch_2020_df.to_csv('pitch_2020.csv')

#pitch_2021_df = download_statcast_data('21', '04-01', '10-03')
#pitch_2021_df.to_csv('pitch_2021.csv')

#pitch_2022_df = download_statcast_data('22', '04-07', '10-05')
#pitch_2022_df.to_csv('pitch_2022.csv')

#pitch_2023_df = download_statcast_data('23', '03-30', '10-01')
#pitch_2023_df.to_csv('pitch_2023.csv')

pitch_2024_df = download_statcast_data('24', '03-20', '09-30')
pitch_2024_df = pitch_2024_df[~((pitch_2024_df['game_date'] == '2024-03-20') & (~pitch_2024_df['home_team'].isin(['LAD', 'SD'])))] # drop non Seoul series games 3/20
pitch_2024_df = pitch_2024_df[~((pitch_2024_df['game_date'] == '2024-03-21') & (~pitch_2024_df['home_team'].isin(['LAD', 'SD'])))] # drop non Seoul series games 3/21
dates_to_drop_24 = ['2024-03-22','2024-03-23', '2024-03-24','2024-03-25', '2024-03-26', '2024-03-27'] # drop all games 3/22-3/27
pitch_2024_df = pitch_2024_df[~pitch_2024_df['game_date'].isin(dates_to_drop_24)]
pitch_2024_df.to_csv('pitch_2024.csv')
# Out:
# Downloading data from 2024-03-20 to 2024-03-31
# This is a large query, it may take a moment to complete
#   0%|          | 0/12 [00:00<?, ?it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   8%|▊         | 1/12 [00:00<00:05,  1.87it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  25%|██▌       | 3/12 [00:01<00:05,  1.50it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  33%|███▎      | 4/12 [00:02<00:04,  1.66it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  42%|████▏     | 5/12 [00:02<00:03,  1.83it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  50%|█████     | 6/12 [00:03<00:03,  1.71it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  58%|█████▊    | 7/12 [00:04<00:03,  1.66it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  67%|██████▋   | 8/12 [00:04<00:02,  1.59it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  75%|███████▌  | 9/12 [00:06<00:02,  1.03it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  83%|████████▎ | 10/12 [00:07<00:01,  1.06it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  92%|█████████▏| 11/12 [00:07<00:00,  1.29it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 12/12 [00:08<00:00,  1.48it/s]
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/statcast.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat(dataframe_list, axis=0).convert_dtypes(convert_string=False)
# Downloading data from 2024-04-01 to 2024-04-30
# This is a large query, it may take a moment to complete
#   0%|          | 0/30 [00:00<?, ?it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|▎         | 1/30 [00:00<00:13,  2.19it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   7%|▋         | 2/30 [00:02<00:31,  1.14s/it]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  13%|█▎        | 4/30 [00:03<00:20,  1.27it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  17%|█▋        | 5/30 [00:03<00:17,  1.42it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  20%|██        | 6/30 [00:04<00:13,  1.74it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  27%|██▋       | 8/30 [00:04<00:09,  2.28it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  30%|███       | 9/30 [00:05<00:09,  2.10it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  33%|███▎      | 10/30 [00:06<00:14,  1.41it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  37%|███▋      | 11/30 [00:08<00:18,  1.02it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  40%|████      | 12/30 [00:08<00:14,  1.22it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  47%|████▋     | 14/30 [00:09<00:10,  1.49it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  50%|█████     | 15/30 [00:09<00:08,  1.80it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  53%|█████▎    | 16/30 [00:10<00:07,  1.88it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  57%|█████▋    | 17/30 [00:12<00:11,  1.14it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  60%|██████    | 18/30 [00:12<00:08,  1.44it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  63%|██████▎   | 19/30 [00:12<00:07,  1.52it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  67%|██████▋   | 20/30 [00:13<00:07,  1.39it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  80%|████████  | 24/30 [00:15<00:03,  2.00it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  93%|█████████▎| 28/30 [00:17<00:00,  2.55it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  97%|█████████▋| 29/30 [00:21<00:01,  1.39s/it]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 30/30 [00:24<00:00,  1.21it/s]
# Downloading data from 2024-05-01 to 2024-05-31
# This is a large query, it may take a moment to complete
#   0%|          | 0/31 [00:00<?, ?it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|▎         | 1/31 [00:00<00:14,  2.06it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   6%|▋         | 2/31 [00:03<00:50,  1.76s/it]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  13%|█▎        | 4/31 [00:03<00:21,  1.24it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  16%|█▌        | 5/31 [00:03<00:16,  1.57it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  19%|█▉        | 6/31 [00:05<00:22,  1.14it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  26%|██▌       | 8/31 [00:05<00:12,  1.88it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  32%|███▏      | 10/31 [00:07<00:15,  1.38it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  35%|███▌      | 11/31 [00:08<00:12,  1.55it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  45%|████▌     | 14/31 [00:09<00:08,  2.07it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  52%|█████▏    | 16/31 [00:11<00:08,  1.69it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  55%|█████▍    | 17/31 [00:11<00:07,  1.92it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  58%|█████▊    | 18/31 [00:12<00:09,  1.43it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  65%|██████▍   | 20/31 [00:13<00:05,  1.85it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  71%|███████   | 22/31 [00:14<00:04,  2.13it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  74%|███████▍  | 23/31 [00:14<00:04,  1.96it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  84%|████████▍ | 26/31 [00:15<00:02,  2.41it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  87%|████████▋ | 27/31 [00:16<00:01,  2.72it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  90%|█████████ | 28/31 [00:16<00:01,  2.52it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  94%|█████████▎| 29/31 [00:18<00:01,  1.24it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
# ...
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  27%|██▋       | 8/30 [00:05<00:08,  2.63it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  30%|███       | 9/30 [00:06<00:15,  1.37it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  33%|███▎      | 10/30 [00:07<00:16,  1.24it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  37%|███▋      | 11/30 [00:08<00:15,  1.24it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  40%|████      | 12/30 [00:09<00:14,  1.22it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  47%|████▋     | 14/30 [00:10<00:10,  1.48it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  53%|█████▎    | 16/30 [00:10<00:06,  2.04it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  57%|█████▋    | 17/30 [00:12<00:10,  1.28it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  60%|██████    | 18/30 [00:13<00:08,  1.44it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  67%|██████▋   | 20/30 [00:14<00:05,  1.69it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  73%|███████▎  | 22/30 [00:14<00:03,  2.43it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  77%|███████▋  | 23/30 [00:15<00:03,  2.11it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  80%|████████  | 24/30 [00:15<00:03,  1.99it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  87%|████████▋ | 26/30 [00:17<00:02,  1.53it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  97%|█████████▋| 29/30 [00:17<00:00,  2.48it/s]/workspaces/final-project-abshire/.conda/lib/python3.11/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 30/30 [00:22<00:00,  1.36it/s]
# /tmp/ipykernel_40685/3430289163.py:98: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   pitch_2024_df = pitch_2024_df[~pitch_2024_df['game_date'].isin(dates_to_drop_24)]

# %%
## step 2: load in, subset for certain columns, concatonate years into 1 df, and save this final df as pitch_2021-2024.csv
def load_df_csv(file_name, df_name):
    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_name)

    # subset cols to keep (explained https://baseballsavant.mlb.com/csv-docs)
    df = df[['batter', 'game_year', 'game_date', 'home_team', 'stand', 'p_throws',
             'pitch_type', 'effective_speed', 'pfx_x', 'pfx_z','plate_x', 'plate_z','zone', 'description',
             'launch_speed', 'launch_angle', 'hc_x', 'hc_y', 'if_fielding_alignment', 'events']]

    return df

#pitch_2015_df = load_df_csv("pitch_2015.csv", "pitch_2015_df")
#pitch_2016_df = load_df_csv("pitch_2016.csv", "pitch_2016_df")
#pitch_2017_df = load_df_csv("pitch_2017.csv", "pitch_2017_df")
#pitch_2018_df = load_df_csv("pitch_2018.csv", "pitch_2018_df")
#pitch_2019_df = load_df_csv("pitch_2019.csv", "pitch_2019_df")
#pitch_2020_df = load_df_csv("pitch_2020.csv", "pitch_2020_df")
#pitch_2021_df = load_df_csv("pitch_2021.csv", "pitch_2021_df")
#pitch_2022_df = load_df_csv("pitch_2022.csv", "pitch_2022_df")
#pitch_2023_df = load_df_csv("pitch_2023.csv", "pitch_2023_df")
pitch_2024_df = load_df_csv("pitch_2024.csv", "pitch_2024_df")

# concatonate dfs into one
batterStatcast = pd.concat([pitch_2024_df], axis=0, ignore_index=True) # axis = 0 to bind by row rather than by col
print(batterStatcast.info())

# write out pitch level data for 2015-24
batterStatcast.to_csv('pitch_2015-2024.csv')

# filter for pitches hit into play and inspect
batterStatcast = batterStatcast[batterStatcast['description'].str.contains('hit_into_play')]
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
print(batterStatcast.info())
print(batterStatcast.head(30))

# write out batted ball data for 2015-24
batterStatcast.to_csv('BIP_2015-2024.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709511 entries, 0 to 709510
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   batter                 709511 non-null  int64
#  1   game_year              709511 non-null  int64
#  2   game_date              709511 non-null  object
#  3   home_team              709511 non-null  object
#  4   stand                  709511 non-null  object
#  5   p_throws               709511 non-null  object
#  6   pitch_type             709224 non-null  object
#  7   effective_speed        708177 non-null  float64
#  8   pfx_x                  709224 non-null  float64
#  9   pfx_z                  709224 non-null  float64
#  10  plate_x                709224 non-null  float64
#  11  plate_z                709224 non-null  float64
#  12  zone                   709224 non-null  float64
#  13  description            709511 non-null  object
#  14  launch_speed           237594 non-null  float64
#  15  launch_angle           237902 non-null  float64
#  16  hc_x                   124153 non-null  float64
#  17  hc_y                   124153 non-null  float64
#  18  if_fielding_alignment  706032 non-null  object
#  19  events                 182175 non-null  object
# dtypes: float64(10), int64(2), object(8)
# memory usage: 108.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 124207 entries, 13 to 709505
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   batter                 124207 non-null  int64
#  1   game_year              124207 non-null  int64
#  2   game_date              124207 non-null  object
#  3   home_team              124207 non-null  object
#  4   stand                  124207 non-null  object
#  5   p_throws               124207 non-null  object
#  6   pitch_type             124161 non-null  object
#  7   effective_speed        123963 non-null  float64
#  8   pfx_x                  124161 non-null  float64
#  9   pfx_z                  124161 non-null  float64
#  10  plate_x                124161 non-null  float64
#  11  plate_z                124161 non-null  float64
#  12  zone                   124161 non-null  float64
#  13  description            124207 non-null  object
#  14  launch_speed           123830 non-null  float64
#  15  launch_angle           123893 non-null  float64
#  16  hc_x                   124153 non-null  float64
#  17  hc_y                   124153 non-null  float64
#  18  if_fielding_alignment  123646 non-null  object
#  19  events                 124206 non-null  object
# dtypes: float64(10), int64(2), object(8)
# memory usage: 19.9+ MB
# None
#      batter  game_year   game_date home_team stand p_throws pitch_type  effective_speed  pfx_x  pfx_z  plate_x  plate_z  zone    description  launch_speed  launch_angle    hc_x    hc_y if_fielding_alignment                     events
# 13   663898       2024  2024-03-31        AZ     R        R         FF             96.6  -0.72   1.19     0.62     2.32   6.0  hit_into_play          96.8          11.0  146.19   77.91              Standard                     single
# 28   666971       2024  2024-03-31        AZ     R        R         SL             84.8   0.21  -0.48     0.51     1.40  14.0  hit_into_play          70.9          13.0   85.81  159.77             Strategic                  field_out
# 32   606466       2024  2024-03-31        AZ     L        R         FF             97.9  -0.54   1.34     0.24     2.31   5.0  hit_into_play          95.7         -14.0  153.09  155.28              Standard                  field_out
# 33   660707       2024  2024-03-31        AZ     R        R         SI             91.0  -1.19  -0.56     0.07     2.37   5.0  hit_into_play          80.3         -20.0  112.55  151.64              Standard  grounded_into_double_play
# 35   666134       2024  2024-03-31        AZ     L        R         SI             90.3  -1.19  -0.61    -0.50     2.57   4.0  hit_into_play          66.0         -57.0  102.26  166.77              Standard                  force_out
# 38   678662       2024  2024-03-31        AZ     R        R         SI             90.8  -1.04  -0.67     0.08     2.51   5.0  hit_into_play         104.5           4.0  125.28  132.20              Standard                     single
# 42   682998       2024  2024-03-31        AZ     L        R         SL             85.3   0.18  -0.75     0.41     1.93   9.0  hit_into_play          69.8           1.0  149.46  152.85             Strategic                  field_out
# 47   672695       2024  2024-03-31        AZ     L        R         FF             98.9  -0.84   1.23     0.30     3.08   3.0  hit_into_play          85.1          60.0   88.95  101.42              Standard                  field_out
# 51   571466       2024  2024-03-31        AZ     L        R         FF             98.4  -0.58   1.27     0.37     2.73   3.0  hit_into_play          83.9           3.0  126.46  144.38         Infield shade                  field_out
# 53   607732       2024  2024-03-31        AZ     R        R         FS             85.7  -0.95   0.84    -0.55     1.82   7.0  hit_into_play          92.2          53.0  128.88   80.84              Standard                  field_out
# 57   595909       2024  2024-03-31        AZ     L        R         FF             93.1  -0.66   1.36    -0.80     2.51   4.0  hit_into_play          96.9         -26.0   72.00  128.04             Strategic                     single
# 63   686668       2024  2024-03-31        AZ     R        R         FF             91.6  -0.79   1.49     0.15     1.81   8.0  hit_into_play          97.6         -31.0   98.02  164.96              Standard                  field_out
# 64   664983       2024  2024-03-31        AZ     L        R         SI             94.5  -1.25   0.32     0.13     1.97   8.0  hit_into_play         106.2          -8.0  150.06  154.07              Standard                  field_out
# 70   592626       2024  2024-03-31        AZ     L        R         SI             95.2  -1.02   0.32     0.06     2.65   5.0  hit_into_play          93.5           3.0  127.07  146.20         Infield shade                  field_out
# 73   669911       2024  2024-03-31        AZ     L        R         FF             91.5  -0.91   1.49     0.17     2.42   5.0  hit_into_play         107.2          32.0  159.95   37.55              Standard                  field_out
# 76   663898       2024  2024-03-31        AZ     R        R         SI             93.0  -1.03   1.39    -0.65     2.93   1.0  hit_into_play          82.3          -6.0  127.07  180.69              Standard                  field_out
# 77   641857       2024  2024-03-31        AZ     L        R         FS             85.0  -1.07   1.00    -0.39     1.82   7.0  hit_into_play          86.5          32.0  121.00   73.11              Standard                  field_out
# 80   572233       2024  2024-03-31        AZ     R        R         SL             89.4   0.51   0.34     0.23     2.39   5.0  hit_into_play          75.5         -14.0  103.47  163.14             Strategic                  field_out
# 81   666971       2024  2024-03-31        AZ     R        R         FF             97.3  -0.53   1.15    -0.34     2.51   4.0  hit_into_play         105.9          19.0   25.57   93.97             Strategic                     double
# 83   606466       2024  2024-03-31        AZ     L        R         SL             90.4   0.51   0.59     0.71     2.71   6.0  hit_into_play          90.3          45.0   79.26  108.08              Standard                field_error
# 85   682998       2024  2024-03-31        AZ     L        R         FF             97.7  -0.20   1.16     0.25     2.92   2.0  hit_into_play          67.7          77.0   85.92  178.88              Standard                  field_out
# 104  660707       2024  2024-03-31        AZ     R        R         SI             94.1  -1.36   0.43    -0.22     2.61   5.0  hit_into_play          96.4         -33.0  105.89  148.62              Standard                  field_out
# 110  666134       2024  2024-03-31        AZ     L        R         FF             93.2  -0.30   1.25     1.01     3.08  12.0  hit_into_play          81.5          78.0  116.78  181.90              Standard                  field_out
# 112  607732       2024  2024-03-31        AZ     R        R         ST             84.5   0.90   0.62     0.51     2.02   6.0  hit_into_play          82.2          14.0  102.86  111.71              Standard                     single
# 114  595909       2024  2024-03-31        AZ     L        R         FF             93.8  -0.39   1.06     0.54     3.13   3.0  hit_into_play          69.2           0.0  110.73  149.83              Standard                  force_out
# 119  686668       2024  2024-03-31        AZ     R        R         SI             92.8  -1.38   0.69    -1.27     2.43  13.0  hit_into_play          41.5         -40.0  121.35  169.85              Standard                     single
# 142  553993       2024  2024-03-31        AZ     R        R         SI             94.8  -1.13   0.78    -0.94     3.03  11.0  hit_into_play          52.5          54.0  132.26  151.84             Strategic                  field_out
# 145  592626       2024  2024-03-31        AZ     L        R         SL             88.4   0.52   0.32     0.74     2.58   6.0  hit_into_play          98.1          65.0  184.09  170.07         Infield shade                  field_out
# 148  663898       2024  2024-03-31        AZ     R        R         ST             87.7   0.50   0.17     0.44     1.67   9.0  hit_into_play         100.3         -22.0  118.60  144.38              Standard                  force_out
# 151  641857       2024  2024-03-31        AZ     L        R         FF             95.4  -0.51   1.36    -0.51     2.47   4.0  hit_into_play          97.5          24.0   67.29   70.67         Infield shade                  field_out

# %%
import pandas as pd
data = pd.read_csv("data/pitch_2015-2024.csv")
print(data['zone'].unique())
# Out:
# [ 2.  8. 14. 12.  1.  7. 13.  6.  4. 11.  3.  5.  9. nan]
