# %%
from pybaseball import statcast
import pandas as pd
from calendar import monthrange

def download_statcast_data(year, start_day, end_day, batter_ids=None):
    """
    Download Statcast data for a given year, with optional batter filter applied immediately.

    Parameters:
    - year: String, last two digits of the year (e.g., '24' for 2024)
    - start_day: String, MM-DD (e.g., '03-01')
    - end_day: String, MM-DD (e.g., '09-30')
    - batter_ids: List of batter IDs to keep (optional). If None, keeps all.
    """
    start_date = f"20{year}-{start_day}"
    end_date = f"20{year}-{end_day}"
    start_month = int(start_day.split('-')[0])
    end_month = int(end_day.split('-')[0])
    list_months = [f"{m:02d}" for m in range(start_month, end_month + 1)]
    
    list_dfs = []
    for i, month in enumerate(list_months):
        if i == 0:
            start = start_date
            _, last_day = monthrange(int(f"20{year}"), int(month))
            end = f"20{year}-{month}-{last_day:02d}" if len(list_months) > 1 else end_date
        elif i == len(list_months) - 1:
            start = f"20{year}-{month}-01"
            end = end_date
        else:
            start = f"20{year}-{month}-01"
            _, last_day = monthrange(int(f"20{year}"), int(month))
            end = f"20{year}-{month}-{last_day:02d}"

        print(f"Downloading data from {start} to {end}")
        data = statcast(start_dt=start, end_dt=end)

        # Filter early to save memory
        if batter_ids is not None:
            data = data[data['batter'].isin(batter_ids)]

        list_dfs.append(data)

    finalDf = pd.concat(list_dfs).drop_duplicates()
    return finalDf

# Your full Top 100 batter IDs
top_100_batters = [
    650333,666182,680757,663538,607208,672695,608070,605141,650490,808982,686469,672580,
    694384,592518,676391,666971,665489,596019,677594,641355,645277,514888,677951,543760,
    669364,680977,671739,593428,667670,691406,663656,680776,665487,694192,521692,670770,
    592206,641487,682928,671218,647304,681624,663697,691718,805779,691026,661388,673237,
    624413,682829,621566,686217,668930,607043,702616,650402,691016,678882,665742,663647,
    571448,672640,678246,683011,676475,666969,673548,650859,668804,660271,642715,683002,
    502671,687401,621493,664023,671277,646240,621020,664034,669701,596115,572233,663993,
    668227,621043,672386,467793,663728,518692,668715,682998,553993,671732,679529,682663,
    681082,682985,575929,592885, 656941
]

# Example usage for 2024 with batter filter
pitch_2024_df = download_statcast_data('24', '03-01', '09-30', batter_ids=top_100_batters)

# Drop Seoul series and other spring games
pitch_2024_df = pitch_2024_df[
    ~((pitch_2024_df['game_date'] == '2024-03-20') & (~pitch_2024_df['home_team'].isin(['LAD', 'SD'])))
]
pitch_2024_df = pitch_2024_df[
    ~((pitch_2024_df['game_date'] == '2024-03-21') & (~pitch_2024_df['home_team'].isin(['LAD', 'SD'])))
]
dates_to_drop_24 = ['2024-03-22','2024-03-23','2024-03-24','2024-03-25','2024-03-26','2024-03-27']
pitch_2024_df = pitch_2024_df[~pitch_2024_df['game_date'].isin(dates_to_drop_24)]

pitch_2024_df.to_csv('pitch_2024_top100.csv', index=False)
# Out:
# Downloading data from 2024-03-01 to 2024-03-31
# This is a large query, it may take a moment to complete
# Skipping offseason dates
#   0%|          | 0/17 [00:00<?, ?it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   6%|▌         | 1/17 [00:04<01:11,  4.50s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  12%|█▏        | 2/17 [00:05<00:35,  2.39s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  18%|█▊        | 3/17 [00:05<00:21,  1.55s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  24%|██▎       | 4/17 [00:06<00:15,  1.21s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  29%|██▉       | 5/17 [00:07<00:12,  1.03s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  35%|███▌      | 6/17 [00:08<00:12,  1.12s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  41%|████      | 7/17 [00:11<00:17,  1.78s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  47%|████▋     | 8/17 [00:12<00:11,  1.33s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  59%|█████▉    | 10/17 [00:12<00:05,  1.30it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  65%|██████▍   | 11/17 [00:13<00:04,  1.37it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  71%|███████   | 12/17 [00:13<00:03,  1.49it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  76%|███████▋  | 13/17 [00:14<00:02,  1.64it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  82%|████████▏ | 14/17 [00:14<00:01,  1.92it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  88%|████████▊ | 15/17 [00:18<00:03,  1.59s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  94%|█████████▍| 16/17 [00:21<00:02,  2.05s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 17/17 [00:23<00:00,  1.37s/it]
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/statcast.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat(dataframe_list, axis=0).convert_dtypes(convert_string=False)
# Downloading data from 2024-04-01 to 2024-04-30
# This is a large query, it may take a moment to complete
#   0%|          | 0/30 [00:00<?, ?it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|▎         | 1/30 [00:00<00:17,  1.67it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  10%|█         | 3/30 [00:01<00:15,  1.74it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  13%|█▎        | 4/30 [00:02<00:14,  1.82it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  17%|█▋        | 5/30 [00:02<00:13,  1.84it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  20%|██        | 6/30 [00:04<00:24,  1.03s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  23%|██▎       | 7/30 [00:05<00:20,  1.11it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  27%|██▋       | 8/30 [00:06<00:20,  1.07it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  30%|███       | 9/30 [00:07<00:17,  1.18it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  33%|███▎      | 10/30 [00:08<00:17,  1.13it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  40%|████      | 12/30 [00:09<00:12,  1.41it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  43%|████▎     | 13/30 [00:09<00:10,  1.56it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  47%|████▋     | 14/30 [00:09<00:07,  2.05it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  50%|█████     | 15/30 [00:10<00:07,  1.92it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  53%|█████▎    | 16/30 [00:11<00:08,  1.70it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  57%|█████▋    | 17/30 [00:11<00:07,  1.66it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  60%|██████    | 18/30 [00:12<00:06,  1.84it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  63%|██████▎   | 19/30 [00:12<00:05,  1.87it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  70%|███████   | 21/30 [00:13<00:04,  1.90it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  73%|███████▎  | 22/30 [00:15<00:06,  1.24it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  77%|███████▋  | 23/30 [00:15<00:05,  1.34it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  80%|████████  | 24/30 [00:16<00:04,  1.33it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  83%|████████▎ | 25/30 [00:17<00:04,  1.21it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  87%|████████▋ | 26/30 [00:19<00:04,  1.08s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  90%|█████████ | 27/30 [00:21<00:04,  1.40s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  93%|█████████▎| 28/30 [00:22<00:02,  1.26s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  97%|█████████▋| 29/30 [00:22<00:01,  1.03s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 30/30 [00:24<00:00,  1.23it/s]
# Downloading data from 2024-05-01 to 2024-05-31
# This is a large query, it may take a moment to complete
#   0%|          | 0/31 [00:00<?, ?it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|▎         | 1/31 [00:01<00:47,  1.58s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   6%|▋         | 2/31 [00:02<00:36,  1.26s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  10%|▉         | 3/31 [00:03<00:30,  1.09s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  13%|█▎        | 4/31 [00:03<00:22,  1.21it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  23%|██▎       | 7/31 [00:05<00:12,  1.90it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  26%|██▌       | 8/31 [00:06<00:15,  1.49it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  29%|██▉       | 9/31 [00:07<00:16,  1.37it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  32%|███▏      | 10/31 [00:08<00:18,  1.12it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  35%|███▌      | 11/31 [00:08<00:13,  1.45it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  42%|████▏     | 13/31 [00:10<00:12,  1.45it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  45%|████▌     | 14/31 [00:10<00:10,  1.60it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  52%|█████▏    | 16/31 [00:12<00:10,  1.45it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  61%|██████▏   | 19/31 [00:13<00:05,  2.07it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  65%|██████▍   | 20/31 [00:14<00:05,  2.03it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  68%|██████▊   | 21/31 [00:14<00:04,  2.01it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  71%|███████   | 22/31 [00:15<00:06,  1.48it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  74%|███████▍  | 23/31 [00:19<00:12,  1.57s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  77%|███████▋  | 24/31 [00:20<00:08,  1.27s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  81%|████████  | 25/31 [00:21<00:07,  1.28s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  84%|████████▍ | 26/31 [00:22<00:05,  1.10s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  87%|████████▋ | 27/31 [00:22<00:03,  1.07it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  90%|█████████ | 28/31 [00:23<00:02,  1.10it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  94%|█████████▎| 29/31 [00:23<00:01,  1.26it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  97%|█████████▋| 30/31 [00:25<00:01,  1.01s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 31/31 [00:32<00:00,  1.04s/it]
# Downloading data from 2024-06-01 to 2024-06-30
# This is a large query, it may take a moment to complete
#   0%|          | 0/30 [00:00<?, ?it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|▎         | 1/30 [00:02<01:00,  2.09s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  10%|█         | 3/30 [00:04<00:32,  1.21s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  23%|██▎       | 7/30 [00:05<00:11,  2.04it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  27%|██▋       | 8/30 [00:05<00:09,  2.33it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  30%|███       | 9/30 [00:06<00:09,  2.14it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  33%|███▎      | 10/30 [00:06<00:09,  2.08it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  37%|███▋      | 11/30 [00:08<00:18,  1.00it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  40%|████      | 12/30 [00:13<00:36,  2.01s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ...
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  27%|██▋       | 8/30 [00:07<00:20,  1.08it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  33%|███▎      | 10/30 [00:07<00:12,  1.55it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  37%|███▋      | 11/30 [00:08<00:11,  1.58it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  47%|████▋     | 14/30 [00:10<00:08,  1.98it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  50%|█████     | 15/30 [00:10<00:07,  1.89it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  53%|█████▎    | 16/30 [00:11<00:08,  1.75it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  57%|█████▋    | 17/30 [00:14<00:17,  1.32s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  60%|██████    | 18/30 [00:14<00:12,  1.01s/it]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  67%|██████▋   | 20/30 [00:14<00:06,  1.62it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  73%|███████▎  | 22/30 [00:16<00:04,  1.61it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  77%|███████▋  | 23/30 [00:16<00:03,  1.76it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  80%|████████  | 24/30 [00:17<00:03,  1.81it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  83%|████████▎ | 25/30 [00:17<00:02,  1.83it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  90%|█████████ | 27/30 [00:19<00:02,  1.46it/s]/home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /home/codespace/.python/current/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 30/30 [00:20<00:00,  1.47it/s]
# /tmp/ipykernel_6614/2522274591.py:71: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   pitch_2024_df = pitch_2024_df[~pitch_2024_df['game_date'].isin(dates_to_drop_24)]

# %%
## https://github.com/stephen1694/pybaseball/blob/main/download_2015_2024.py

## step 1: download pitch level data for each year

# import modules
from pybaseball import statcast
import pandas as pd
from calendar import monthrange

def download_statcast_data(year, start_day, end_day):
    """
    Download Statcast data for a given year, starting and ending at specific dates.

    Parameters:
    - year: String, last two digits of the year (e.g., '15' for 2015)
    - start_day: String, the starting day in 'MM-DD' format (e.g., '03-15' for March 15)
    - end_day: String, the ending day in 'MM-DD' format (e.g., '10-05' for October 5)

    Returns finalDf: DataFrame with Statcast data for the specified range of the season
    """
    # Convert start and end days to full dates
    start_date = f"20{year}-{start_day}"
    end_date = f"20{year}-{end_day}"

    # Extract start and end months
    start_month = int(start_day.split('-')[0])
    end_month = int(end_day.split('-')[0])

    # Generate the list of months between the start and end
    list_months = [f"{month:02d}" for month in range(start_month, end_month + 1)]

    # Make an empty list for dataframes
    list_dfs = []

    # Download Statcast data month by month
    for i, month in enumerate(list_months):
        # Define start and end dates for the month
        if i == 0:  # First month
            start = start_date
            _, last_day = monthrange(int(f"20{year}"), int(month))
            end = f"20{year}-{month}-{last_day:02d}" if len(list_months) > 1 else end_date
        elif i == len(list_months) - 1:  # Last month
            start = f"20{year}-{month}-01"
            end = end_date
        else:  # Middle months
            start = f"20{year}-{month}-01"
            _, last_day = monthrange(int(f"20{year}"), int(month))
            end = f"20{year}-{month}-{last_day:02d}"

        print(f"Downloading data from {start} to {end}")
        data = statcast(start_dt=start, end_dt=end)
        list_dfs.append(data)

    # Concatenate dataframes in list_dfs to one dataframe called finalDf
    finalDf = pd.concat(list_dfs)

    # Drop duplicates from finalDf
    finalDf = finalDf.drop_duplicates()

    return finalDf

#pitch_2015_df = download_statcast_data('25', '04-10', '04-15')
#pitch_2015_df.to_csv('pitch_2015.csv')

#pitch_2016_df = download_statcast_data('16', '04-03', '10-02')
#pitch_2016_df = pitch_2016_df[~((pitch_2016_df['game_date'] == '2016-04-03') & (~pitch_2016_df['home_team'].isin(['PIT', 'KC', 'TB'])))] # drop spring games ((all except PIT, KC, TB home games)
#pitch_2016_df.to_csv('pitch_2016.csv')

#pitch_2017_df = download_statcast_data('17', '04-02', '10-01')
#pitch_2017_df.to_csv('pitch_2017.csv')

#pitch_2018_df = download_statcast_data('18', '03-29', '10-01')
#pitch_2018_df.to_csv('pitch_2018.csv')

#pitch_2019_df = download_statcast_data('19', '03-20', '09-30')
#pitch_2019_df = pitch_2019_df[~((pitch_2019_df['game_date'] == '2019-03-20') & (~pitch_2019_df['home_team'].isin(['SEA', 'OAK'])))] # drop non Japan series games 3/20
#pitch_2019_df = pitch_2019_df[~((pitch_2019_df['game_date'] == '2019-03-21') & (~pitch_2019_df['home_team'].isin(['SEA', 'OAK'])))] # drop non Japan series games 3/21
#dates_to_drop_19 = ['2019-03-22','2019-03-23','2019-03-24','2019-03-25','2019-03-26','2019-03-27'] # drop all games 3/22-3/27
#pitch_2019_df = pitch_2019_df[~pitch_2019_df['game_date'].isin(dates_to_drop_19)]
#pitch_2019_df.to_csv('pitch_2019.csv')

#pitch_2020_df = download_statcast_data('20', '07-23', '09-27')
#pitch_2020_df.to_csv('pitch_2020.csv')

#pitch_2021_df = download_statcast_data('21', '04-01', '10-03')
#pitch_2021_df.to_csv('pitch_2021.csv')

#pitch_2022_df = download_statcast_data('22', '04-07', '10-05')
#pitch_2022_df.to_csv('pitch_2022.csv')

#pitch_2023_df = download_statcast_data('23', '03-30', '10-01')
#pitch_2023_df.to_csv('pitch_2023.csv')

pitch_2024_df = download_statcast_data('24', '03-01', '09-30')
pitch_2024_df = pitch_2024_df[~((pitch_2024_df['game_date'] == '2024-03-20') & (~pitch_2024_df['home_team'].isin(['LAD', 'SD'])))] # drop non Seoul series games 3/20
pitch_2024_df = pitch_2024_df[~((pitch_2024_df['game_date'] == '2024-03-21') & (~pitch_2024_df['home_team'].isin(['LAD', 'SD'])))] # drop non Seoul series games 3/21
dates_to_drop_24 = ['2024-03-22','2024-03-23', '2024-03-24','2024-03-25', '2024-03-26', '2024-03-27'] # drop all games 3/22-3/27
pitch_2024_df = pitch_2024_df[~pitch_2024_df['game_date'].isin(dates_to_drop_24)]
pitch_2024_df.to_csv('pitch_2024_all.csv')

# %% [markdown]
# ### Need to combine month data because Kernel was failing after changing variables?

# %%
import pandas as pd

files = [
    '/workspaces/final-project-abshire/data/monthly data/pitch_2024_march.csv',
    '/workspaces/final-project-abshire/data/monthly data/pitch_2024_april.csv',
    '/workspaces/final-project-abshire/data/monthly data/pitch_2024_may.csv',
    '/workspaces/final-project-abshire/data/monthly data/pitch_2024_june.csv',
    '/workspaces/final-project-abshire/data/monthly data/pitch_2024_july.csv',
    '/workspaces/final-project-abshire/data/monthly data/pitch_2024_august.csv',
    '/workspaces/final-project-abshire/data/monthly data/pitch_2024_september.csv'
]

dfs = []
for f in files:
    try:
        df_tmp = pd.read_csv(f)
        print(f"Loaded {f} with shape {df_tmp.shape}")
        dfs.append(df_tmp)
    except Exception as e:
        print(f"Error loading {f}: {e}")

if dfs:
    combined_df = pd.concat(dfs, ignore_index=True)
    combined_df.to_csv('/workspaces/final-project-abshire/data/pitch_2024_new.csv', index=False)
    print(f"Saved combined file with {len(combined_df)} rows")
else:
    print("No files loaded, combined DataFrame is empty.")

# %%
import pandas as pd

## step 2: load in, subset for certain columns, concatonate years into 1 df, and save this final df as pitch_2021-2024.csv
def load_df_csv(file_name, df_name):
    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_name)

    # subset cols to keep (explained https://baseballsavant.mlb.com/csv-docs)
    df = df[['batter', 'player_name', 'game_date', 'stand', 'p_throws',
             'pitch_type', 'effective_speed', 'pfx_x', 'pfx_z','plate_x', 'plate_z','zone', 'description',
             'launch_speed', 'launch_angle', 'hc_x', 'hc_y', 'if_fielding_alignment', 'events']]

    return df

#pitch_2015_df = load_df_csv("pitch_2015.csv", "pitch_2015_df")
#pitch_2016_df = load_df_csv("pitch_2016.csv", "pitch_2016_df")
#pitch_2017_df = load_df_csv("pitch_2017.csv", "pitch_2017_df")
#pitch_2018_df = load_df_csv("pitch_2018.csv", "pitch_2018_df")
#pitch_2019_df = load_df_csv("pitch_2019.csv", "pitch_2019_df")
#pitch_2020_df = load_df_csv("pitch_2020.csv", "pitch_2020_df")
#pitch_2021_df = load_df_csv("pitch_2021.csv", "pitch_2021_df")
#pitch_2022_df = load_df_csv("pitch_2022.csv", "pitch_2022_df")
#pitch_2023_df = load_df_csv("pitch_2023.csv", "pitch_2023_df")
pitch_2024_df = load_df_csv("/workspaces/final-project-abshire/notebooks/pitch_2024_top100.csv", "pitch_2024_top100test_huh")

# concatonate dfs into one
batterStatcast = pd.concat([pitch_2024_df], axis=0, ignore_index=True) # axis = 0 to bind by row rather than by col
print(batterStatcast.info())

# write out pitch level data for 2015-24
batterStatcast.to_csv('pitch_2024_top100_reduced.csv')

# filter for pitches hit into play and inspect
batterStatcast = batterStatcast[batterStatcast['description'].str.contains('hit_into_play')]
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
print(batterStatcast.info())
print(batterStatcast.head(30))

# write out batted ball data for 2015-24
batterStatcast.to_csv('BIP_2024_top100.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213919 entries, 0 to 213918
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   batter                 213919 non-null  int64
#  1   player_name            213919 non-null  object
#  2   game_date              213919 non-null  object
#  3   stand                  213919 non-null  object
#  4   p_throws               213919 non-null  object
#  5   pitch_type             212806 non-null  object
#  6   effective_speed        212458 non-null  float64
#  7   pfx_x                  212806 non-null  float64
#  8   pfx_z                  212806 non-null  float64
#  9   plate_x                212806 non-null  float64
#  10  plate_z                212806 non-null  float64
#  11  zone                   212806 non-null  float64
#  12  description            213919 non-null  object
#  13  launch_speed           73118 non-null   float64
#  14  launch_angle           73205 non-null   float64
#  15  hc_x                   38837 non-null   float64
#  16  hc_y                   38837 non-null   float64
#  17  if_fielding_alignment  211698 non-null  object
#  18  events                 55108 non-null   object
# dtypes: float64(10), int64(1), object(8)
# memory usage: 31.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 38848 entries, 6 to 213913
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   batter                 38848 non-null  int64
#  1   player_name            38848 non-null  object
#  2   game_date              38848 non-null  object
#  3   stand                  38848 non-null  object
#  4   p_throws               38848 non-null  object
#  5   pitch_type             38515 non-null  object
#  6   effective_speed        38452 non-null  float64
#  7   pfx_x                  38515 non-null  float64
#  8   pfx_z                  38515 non-null  float64
#  9   plate_x                38515 non-null  float64
#  10  plate_z                38515 non-null  float64
#  11  zone                   38515 non-null  float64
#  12  description            38848 non-null  object
#  13  launch_speed           38428 non-null  float64
#  14  launch_angle           38445 non-null  float64
#  15  hc_x                   38837 non-null  float64
#  16  hc_y                   38837 non-null  float64
#  17  if_fielding_alignment  38333 non-null  object
#  18  events                 38848 non-null  object
# dtypes: float64(10), int64(1), object(8)
# memory usage: 5.9+ MB
# None
#      batter     player_name   game_date stand p_throws pitch_type  effective_speed  pfx_x  pfx_z  plate_x  plate_z  zone    description  launch_speed  launch_angle    hc_x    hc_y if_fielding_alignment                     events
# 6    666971  Vodnik, Victor  2024-03-31     R        R         SL             84.8   0.21  -0.48     0.51     1.40  14.0  hit_into_play          70.9          13.0   85.81  159.77             Strategic                  field_out
# 10   682998  Vodnik, Victor  2024-03-31     L        R         SL             85.3   0.18  -0.75     0.41     1.93   9.0  hit_into_play          69.8           1.0  149.46  152.85             Strategic                  field_out
# 15   672695  Vodnik, Victor  2024-03-31     L        R         FF             98.9  -0.84   1.23     0.30     3.08   3.0  hit_into_play          85.1          60.0   88.95  101.42              Standard                  field_out
# 23   572233   Feltner, Ryan  2024-03-31     R        R         SL             89.4   0.51   0.34     0.23     2.39   5.0  hit_into_play          75.5         -14.0  103.47  163.14             Strategic                  field_out
# 24   666971   Feltner, Ryan  2024-03-31     R        R         FF             97.3  -0.53   1.15    -0.34     2.51   4.0  hit_into_play         105.9          19.0   25.57   93.97             Strategic                     double
# 26   682998   Feltner, Ryan  2024-03-31     L        R         FF             97.7  -0.20   1.16     0.25     2.92   2.0  hit_into_play          67.7          77.0   85.92  178.88              Standard                  field_out
# 39   553993   Feltner, Ryan  2024-03-31     R        R         SI             94.8  -1.13   0.78    -0.94     3.03  11.0  hit_into_play          52.5          54.0  132.26  151.84             Strategic                  field_out
# 44   666971   Feltner, Ryan  2024-03-31     R        R         SL             91.5   0.08   0.44     0.32     2.62   6.0  hit_into_play          99.6          25.0  140.32   44.09             Strategic                  field_out
# 50   682998   Feltner, Ryan  2024-03-31     L        R         FF             96.3  -0.23   1.21     0.42     2.76   3.0  hit_into_play          70.2          48.0   98.96  120.55         Infield shade                  field_out
# 52   672695   Feltner, Ryan  2024-03-31     L        R         SL             89.7   0.42   0.41     0.63     2.58   6.0  hit_into_play          81.2         -10.0  151.27  171.01         Infield shade  grounded_into_double_play
# 56   553993   Feltner, Ryan  2024-03-31     R        R         SL             89.7   0.45   0.32    -0.09     2.61   5.0  hit_into_play          88.3           4.0  102.26  163.14              Standard            fielders_choice
# 60   572233   Feltner, Ryan  2024-03-31     R        R         ST             83.3   0.92  -0.07     0.10     1.56   8.0  hit_into_play         103.9          25.0   75.03   38.49             Strategic                   home_run
# 64   666971   Feltner, Ryan  2024-03-31     R        R         FF             96.7  -0.25   1.24     0.37     2.99   6.0  hit_into_play         106.1           6.0  124.04   91.74             Strategic                     single
# 74   650859   Cano, Yennier  2024-03-31     L        R         CH             89.5  -1.72   0.00    -1.20     1.59  13.0  hit_into_play          90.2         -23.0  116.19  146.21              Standard                  field_out
# 79   621493   Cano, Yennier  2024-03-31     R        R         SI             94.7  -1.62  -0.32    -0.30     2.40   4.0  hit_into_play          89.3         -20.0  110.04  145.83              Standard                  field_out
# 82   694384     Webb, Jacob  2024-03-31     L        R         FF             91.6  -0.89   1.64     0.51     3.17   3.0  hit_into_play          86.8          53.0  175.55  119.08              Standard                  field_out
# 84   683002   Soriano, José  2024-03-31     L        R         SI             99.1  -1.36   0.56    -0.23     1.45  13.0  hit_into_play          85.9         -24.0  144.59  157.63              Standard                  force_out
# 85   650859    Tate, Dillon  2024-03-31     L        R         SI             94.2  -1.39   0.34    -0.53     1.64   7.0  hit_into_play          93.0         -12.0  148.16  151.80              Standard                  field_out
# 95   694384    Wells, Tyler  2024-03-31     L        R         SL             83.7   0.62  -0.01     0.03     2.26   5.0  hit_into_play         100.3           0.0  152.22  150.27             Strategic                  field_out
# 99   650859    Wells, Tyler  2024-03-31     L        R         CH             87.3  -1.35   1.19    -1.00     1.97  13.0  hit_into_play          83.9         -36.0  140.06  135.87             Strategic                  field_out
# 104  621493    Wells, Tyler  2024-03-31     R        R         CH             87.3  -1.45   1.06    -0.08     2.66   5.0  hit_into_play         104.7           6.0   98.86  137.98         Infield shade                  field_out
# 112  694384    Wells, Tyler  2024-03-31     L        R         CH             87.4  -1.27   1.28    -0.81     1.89   7.0  hit_into_play          64.5         -50.0  129.79  184.58              Standard                  field_out
# 117  650859    Wells, Tyler  2024-03-31     L        R         FF             91.7  -0.78   1.54    -1.09     2.88  11.0  hit_into_play          60.5         -85.0  123.41  198.53              Standard                     single
# 120  683002   Detmers, Reid  2024-03-31     L        L         SL             83.9  -0.44  -0.18     0.93     2.76  12.0  hit_into_play          88.3          11.0  167.15  156.32         Infield shade                  field_out
# 123  621493    Wells, Tyler  2024-03-31     R        R         FF             93.1  -0.62   1.76    -0.26     2.15   8.0  hit_into_play         107.6          25.0   27.53   70.27         Infield shade                   home_run
# 125  694384    Wells, Tyler  2024-03-31     L        R         CU             76.5   0.81  -0.98    -0.36     1.51  13.0  hit_into_play          73.1          28.0  150.73   97.71             Strategic                     single
# 140  682985   Banks, Tanner  2024-03-31     L        L         SL             85.5  -0.55   0.26     0.65     2.07   9.0  hit_into_play          71.0           9.0  131.19  135.95              Standard                  field_out
# 159  679529    Fedde, Erick  2024-03-31     R        R         ST             84.7   0.82   0.22     0.92     1.57  14.0  hit_into_play          86.3         -41.0  107.46  159.87              Standard                  field_out
# 162  682985    Fedde, Erick  2024-03-31     L        R         FC             90.7   0.00   0.57    -0.18     1.81   8.0  hit_into_play          67.6         -34.0  133.73  182.87              Standard                  field_out
# 167  663697  Finnegan, Kyle  2024-03-31     R        R         FF             97.4  -0.71   1.41    -0.55     2.23   4.0  hit_into_play          80.3          16.0   63.39  139.91              Standard                     double

# %%
import pandas as pd

# Load data
pitch_df = pd.read_csv('/workspaces/final-project-abshire/notebooks/pitch_2024_top100_reduced.csv')
player_ids_df = pd.read_csv('/workspaces/final-project-abshire/data/player_ids.csv')

# Prepare player IDs
player_ids_sub = player_ids_df[['MLBAMID', 'Name']].rename(columns={'Name': 'batter_name'})

# Merge on batter and MLBAMID
df_top100 = pitch_df.merge(player_ids_sub, left_on='batter', right_on='MLBAMID', how='left')
df_top100 = df_top100.drop(columns=['MLBAMID'])
df_top100 = df_top100.rename(columns={'player_name': 'pitcher_name'})

# Filter to hitting events only
hitting_events = ['single', 'double', 'triple', 'home_run']
df_hits = df_top100[df_top100['events'].isin(hitting_events)].copy()

# Now define your pitch_type_map
pitch_type_map = {
    'FF': 'Fastball',  # Four-Seam
    'FA': 'Fastball',  # General Fastball
    'FT': 'Fastball',  # Two-Seam
    'SI': 'Fastball',  # Sinker
    'FS': 'Fastball',  # Split Finger
    'SL': 'Slider',    # Slider
    'SV': 'Slider',    # Slurve
    'ST': 'Curveball', # Sweeper
    'CU': 'Curveball', # Curveball
    'KC': 'Curveball', # Knuckle Curve
    'CH': 'Changeup',  # Change Up
    'FO': 'Changeup',  # Fork Ball
    'EP': 'Changeup',  # Eephus
    'FC': 'Fastball',  # Cutter
    'KN': 'Knuckleball', # Knuckleball
    'SC': 'Other',     # Screwball
    'CS': 'Other',     # Slow Curve
    'PO': 'Other',     # Pitch Out?
    None: 'Unknown',   # or np.nan mapped to 'Unknown'
    'NaN': 'Unknown'   # if string 'NaN'
}

# Map pitch_type to pitch_group column
df_top100['pitch_group'] = df_top100['pitch_type'].map(pitch_type_map).fillna('Unknown')

print(df_top100.head())

# Unique count of batter_name
unique_batter_count = df_top100['batter_name'].nunique()
print(f"Unique batter_name count: {unique_batter_count}")

# Print the unique batter names
unique_batters = df_top100['batter_name'].unique()
print("Unique batter names:")
print(unique_batters)
# Out:
#    Unnamed: 0  batter    pitcher_name   game_date stand p_throws pitch_type  effective_speed  pfx_x  pfx_z  plate_x  plate_z  zone    description  launch_speed  launch_angle  hc_x  hc_y if_fielding_alignment     events       batter_name pitch_group
# 0           0  572233  Vodnik, Victor  2024-03-31     R        R         SL             85.5   0.33  -0.22     0.89     1.92  14.0  called_strike           NaN           NaN   NaN   NaN             Strategic  strikeout  Christian Walker      Slider
# 1           1  572233  Vodnik, Victor  2024-03-31     R        R         SL             88.0   0.03  -0.41     1.53    -0.62  14.0           ball           NaN           NaN   NaN   NaN             Strategic        NaN  Christian Walker      Slider
# 2           2  572233  Vodnik, Victor  2024-03-31     R        R         FF             99.5  -0.31   1.36    -0.20     3.25   2.0           foul          81.1          17.0   NaN   NaN             Strategic        NaN  Christian Walker    Fastball
# 3           3  572233  Vodnik, Victor  2024-03-31     R        R         FF            100.5  -0.20   1.27     0.30     3.12   3.0           foul          81.1          21.0   NaN   NaN             Strategic        NaN  Christian Walker    Fastball
# 4           4  572233  Vodnik, Victor  2024-03-31     R        R         FF            100.3  -0.65   1.15     0.50     2.21   6.0           foul          75.0          30.0   NaN   NaN             Strategic        NaN  Christian Walker    Fastball
# Unique batter_name count: 100
# Unique batter names:
# ['Christian Walker' 'Lourdes Gurriel Jr.' 'Corbin Carroll'
#  'Geraldo Perdomo' 'Eugenio Suarez' 'Luis Rengifo' 'Taylor Ward'
#  'Nolan Schanuel' 'Gunnar Henderson' 'Spencer Torkelson' 'Riley Greene'
#  'Jonathan India' 'Spencer Steer' 'Elly De La Cruz' 'CJ Abrams'
#  'Luis Garcia' 'Kyle Tucker' 'Jose Altuve' 'Juan Soto' 'Gleyber Torres'
#  'Yainer Diaz' 'Carlos Santana' 'Salvador Perez' 'Vinnie Pasquantino'
#  'Bobby Witt Jr.' 'Maikel Garcia' 'Carlos Correa' 'Nolan Arenado'
#  'Paul Goldschmidt' 'Freddie Freeman' 'Brendan Donovan' 'Masyn Winn'
#  'Shohei Ohtani' 'Mookie Betts' 'Alec Burleson' 'Willson Contreras'
#  'Ke’Bryan Hayes' 'Bryan Reynolds' 'Luis Arraez' 'Willy Adames'
#  'Christian Yelich' 'Pete Alonso' 'William Contreras' 'Sal Frelick'
#  'Jackson Chourio' 'Brice Turang' 'Joey Ortiz' 'Francisco Lindor'
#  'Brandon Nimmo' 'Lawrence Butler' 'Steven Kwan' 'Josh Naylor'
#  'Jose Ramirez' 'Michael Harris II' 'Bryson Stott' 'Matt Olson'
#  'Ozzie Albies' 'Nick Castellanos' 'Trea Turner' 'Kyle Schwarber'
#  'Jung Hoo Lee' 'Manny Machado' 'Fernando Tatis Jr.' 'Xander Bogaerts'
#  'Ty France' 'Rafael Devers' 'Jarren Duran' 'Julio Rodriguez'
#  'J.P. Crawford' 'Trevor Story' 'Ernie Clement' 'Alejandro Kirk'
#  'Vladimir Guerrero Jr.' 'Randy Arozarena' 'Yandy Diaz' 'Josh H. Smith'
#  'Adolis Garcia' 'Cody Bellinger' 'Seiya Suzuki' 'Ian Happ' 'Nico Hoerner'
#  'Dansby Swanson' 'Marcus Semien' 'Anthony Volpe' 'Brent Rooker'
#  'Cal Raleigh' 'Ceddanne Rafaela' 'Bo Bichette' 'Jackson Holliday'
#  'Jacob Wilson' 'Otto Lopez' 'Tyler Soderstrom' 'TJ Friedl' 'Heliot Ramos'
#  'Andy Pages' 'Pete Crow-Armstrong' 'Nathaniel Lowe' 'Miguel Vargas'
#  'Xavier Edwards' 'Junior Caminero']
